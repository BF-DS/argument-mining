# %%
import pandas as pd
import os

# %% [markdown]
# # Dateien laden

# %%
# Example usage
FILES_PATH = 'Essays/ArgumentAnnotatedEssays-2.0/brat-project-final/'
example_file = 'essay001.ann'
example_file_path = FILES_PATH + example_file

def list_files(data_path):
    return os.listdir(data_path)

def list_files_with_extension(data_path, extension):
    return [f for f in os.listdir(data_path) if f.endswith(extension)]

def list_files_with_extension_directory(data_path, extension):  
    return [FILES_PATH + f for f in os.listdir(data_path) if f.endswith(extension)]
# "FileName": os.path.basename(pdf) # get the file name without the path

# %%
list_files(FILES_PATH)
# Out:
# ['.DS_Store',
#  '.stats_cache',
#  'annotation.conf',
#  'essay001.ann',
#  'essay001.txt',
#  'essay002.ann',
#  'essay002.txt',
#  'essay003.ann',
#  'essay003.txt',
#  'essay004.ann',
#  'essay004.txt',
#  'essay005.ann',
#  'essay005.txt',
#  'essay006.ann',
#  'essay006.txt',
#  'essay007.ann',
#  'essay007.txt',
#  'essay008.ann',
#  'essay008.txt',
#  'essay009.ann',
#  'essay009.txt',
#  'essay010.ann',
#  'essay010.txt',
#  'essay011.ann',
#  'essay011.txt',
#  'essay012.ann',
#  'essay012.txt',
#  'essay013.ann',
#  'essay013.txt',
#  'essay014.ann',
#  'essay014.txt',
#  'essay015.ann',
#  'essay015.txt',
#  'essay016.ann',
#  'essay016.txt',
#  'essay017.ann',
#  'essay017.txt',
#  'essay018.ann',
#  'essay018.txt',
#  'essay019.ann',
#  'essay019.txt',
#  'essay020.ann',
#  'essay020.txt',
#  'essay021.ann',
#  'essay021.txt',
#  'essay022.ann',
#  'essay022.txt',
#  'essay023.ann',
#  'essay023.txt',
#  'essay024.ann',
#  'essay024.txt',
#  'essay025.ann',
#  'essay025.txt',
#  'essay026.ann',
#  'essay026.txt',
#  'essay027.ann',
#  'essay027.txt',
#  'essay028.ann',
#  'essay028.txt',
#  'essay029.ann',
#  'essay029.txt',
#  'essay030.ann',
#  'essay030.txt',
#  'essay031.ann',
#  'essay031.txt',
#  'essay032.ann',
#  'essay032.txt',
#  'essay033.ann',
#  'essay033.txt',
#  'essay034.ann',
#  'essay034.txt',
#  'essay035.ann',
#  'essay035.txt',
#  'essay036.ann',
#  'essay036.txt',
#  'essay037.ann',
#  'essay037.txt',
#  'essay038.ann',
#  'essay038.txt',
#  'essay039.ann',
#  'essay039.txt',
#  'essay040.ann',
#  'essay040.txt',
#  'essay041.ann',
#  'essay041.txt',
#  'essay042.ann',
#  'essay042.txt',
#  'essay043.ann',
#  'essay043.txt',
#  'essay044.ann',
#  'essay044.txt',
#  'essay045.ann',
#  'essay045.txt',
#  'essay046.ann',
#  'essay046.txt',
#  'essay047.ann',
#  'essay047.txt',
#  'essay048.ann',
#  'essay048.txt',
#  'essay049.ann',
#  'essay049.txt',
#  'essay050.ann',
#  'essay050.txt',
#  'essay051.ann',
#  'essay051.txt',
#  'essay052.ann',
#  'essay052.txt',
#  'essay053.ann',
#  'essay053.txt',
#  'essay054.ann',
#  'essay054.txt',
#  'essay055.ann',
#  'essay055.txt',
#  'essay056.ann',
#  'essay056.txt',
#  'essay057.ann',
#  'essay057.txt',
#  'essay058.ann',
#  'essay058.txt',
#  'essay059.ann',
#  'essay059.txt',
#  'essay060.ann',
#  'essay060.txt',
#  'essay061.ann',
#  'essay061.txt',
#  'essay062.ann',
#  'essay062.txt',
#  'essay063.ann',
#  'essay063.txt',
#  'essay064.ann',
#  'essay064.txt',
#  'essay065.ann',
#  'essay065.txt',
#  'essay066.ann',
#  'essay066.txt',
#  'essay067.ann',
#  'essay067.txt',
#  'essay068.ann',
#  'essay068.txt',
#  'essay069.ann',
#  'essay069.txt',
#  'essay070.ann',
#  'essay070.txt',
#  'essay071.ann',
#  'essay071.txt',
#  'essay072.ann',
#  'essay072.txt',
#  'essay073.ann',
#  'essay073.txt',
#  'essay074.ann',
#  'essay074.txt',
#  'essay075.ann',
#  'essay075.txt',
#  'essay076.ann',
#  'essay076.txt',
#  'essay077.ann',
#  'essay077.txt',
#  'essay078.ann',
#  'essay078.txt',
#  'essay079.ann',
#  'essay079.txt',
#  'essay080.ann',
#  'essay080.txt',
#  'essay081.ann',
#  'essay081.txt',
#  'essay082.ann',
#  'essay082.txt',
#  'essay083.ann',
#  'essay083.txt',
#  'essay084.ann',
#  'essay084.txt',
#  'essay085.ann',
#  'essay085.txt',
#  'essay086.ann',
#  'essay086.txt',
#  'essay087.ann',
#  'essay087.txt',
#  'essay088.ann',
#  'essay088.txt',
#  'essay089.ann',
#  'essay089.txt',
#  'essay090.ann',
#  'essay090.txt',
#  'essay091.ann',
#  'essay091.txt',
#  'essay092.ann',
#  'essay092.txt',
#  'essay093.ann',
#  'essay093.txt',
#  'essay094.ann',
#  'essay094.txt',
#  'essay095.ann',
#  'essay095.txt',
#  'essay096.ann',
#  'essay096.txt',
#  'essay097.ann',
#  'essay097.txt',
#  'essay098.ann',
#  'essay098.txt',
#  'essay099.ann',
#  'essay099.txt',
#  'essay100.ann',
#  'essay100.txt',
#  'essay101.ann',
#  'essay101.txt',
#  'essay102.ann',
#  'essay102.txt',
#  'essay103.ann',
#  'essay103.txt',
#  'essay104.ann',
#  'essay104.txt',
#  'essay105.ann',
#  'essay105.txt',
#  'essay106.ann',
#  'essay106.txt',
#  'essay107.ann',
#  'essay107.txt',
#  'essay108.ann',
#  'essay108.txt',
#  'essay109.ann',
#  'essay109.txt',
#  'essay110.ann',
#  'essay110.txt',
#  'essay111.ann',
#  'essay111.txt',
#  'essay112.ann',
#  'essay112.txt',
#  'essay113.ann',
#  'essay113.txt',
#  'essay114.ann',
#  'essay114.txt',
#  'essay115.ann',
#  'essay115.txt',
#  'essay116.ann',
#  'essay116.txt',
#  'essay117.ann',
#  'essay117.txt',
#  'essay118.ann',
#  'essay118.txt',
#  'essay119.ann',
#  'essay119.txt',
#  'essay120.ann',
#  'essay120.txt',
#  'essay121.ann',
#  'essay121.txt',
#  'essay122.ann',
#  'essay122.txt',
#  'essay123.ann',
#  'essay123.txt',
#  'essay124.ann',
#  'essay124.txt',
#  'essay125.ann',
#  'essay125.txt',
#  'essay126.ann',
#  'essay126.txt',
#  'essay127.ann',
#  'essay127.txt',
#  'essay128.ann',
#  'essay128.txt',
#  'essay129.ann',
#  'essay129.txt',
#  'essay130.ann',
#  'essay130.txt',
#  'essay131.ann',
#  'essay131.txt',
#  'essay132.ann',
#  'essay132.txt',
#  'essay133.ann',
#  'essay133.txt',
#  'essay134.ann',
#  'essay134.txt',
#  'essay135.ann',
#  'essay135.txt',
#  'essay136.ann',
#  'essay136.txt',
#  'essay137.ann',
#  'essay137.txt',
#  'essay138.ann',
#  'essay138.txt',
#  'essay139.ann',
#  'essay139.txt',
#  'essay140.ann',
#  'essay140.txt',
#  'essay141.ann',
#  'essay141.txt',
#  'essay142.ann',
#  'essay142.txt',
#  'essay143.ann',
#  'essay143.txt',
#  'essay144.ann',
#  'essay144.txt',
#  'essay145.ann',
#  'essay145.txt',
#  'essay146.ann',
#  'essay146.txt',
#  'essay147.ann',
#  'essay147.txt',
#  'essay148.ann',
#  'essay148.txt',
#  'essay149.ann',
#  'essay149.txt',
#  'essay150.ann',
#  'essay150.txt',
#  'essay151.ann',
#  'essay151.txt',
#  'essay152.ann',
#  'essay152.txt',
#  'essay153.ann',
#  'essay153.txt',
#  'essay154.ann',
#  'essay154.txt',
#  'essay155.ann',
#  'essay155.txt',
#  'essay156.ann',
#  'essay156.txt',
#  'essay157.ann',
#  'essay157.txt',
#  'essay158.ann',
#  'essay158.txt',
#  'essay159.ann',
#  'essay159.txt',
#  'essay160.ann',
#  'essay160.txt',
#  'essay161.ann',
#  'essay161.txt',
#  'essay162.ann',
#  'essay162.txt',
#  'essay163.ann',
#  'essay163.txt',
#  'essay164.ann',
#  'essay164.txt',
#  'essay165.ann',
#  'essay165.txt',
#  'essay166.ann',
#  'essay166.txt',
#  'essay167.ann',
#  'essay167.txt',
#  'essay168.ann',
#  'essay168.txt',
#  'essay169.ann',
#  'essay169.txt',
#  'essay170.ann',
#  'essay170.txt',
#  'essay171.ann',
#  'essay171.txt',
#  'essay172.ann',
#  'essay172.txt',
#  'essay173.ann',
#  'essay173.txt',
#  'essay174.ann',
#  'essay174.txt',
#  'essay175.ann',
#  'essay175.txt',
#  'essay176.ann',
#  'essay176.txt',
#  'essay177.ann',
#  'essay177.txt',
#  'essay178.ann',
#  'essay178.txt',
#  'essay179.ann',
#  'essay179.txt',
#  'essay180.ann',
#  'essay180.txt',
#  'essay181.ann',
#  'essay181.txt',
#  'essay182.ann',
#  'essay182.txt',
#  'essay183.ann',
#  'essay183.txt',
#  'essay184.ann',
#  'essay184.txt',
#  'essay185.ann',
#  'essay185.txt',
#  'essay186.ann',
#  'essay186.txt',
#  'essay187.ann',
#  'essay187.txt',
#  'essay188.ann',
#  'essay188.txt',
#  'essay189.ann',
#  'essay189.txt',
#  'essay190.ann',
#  'essay190.txt',
#  'essay191.ann',
#  'essay191.txt',
#  'essay192.ann',
#  'essay192.txt',
#  'essay193.ann',
#  'essay193.txt',
#  'essay194.ann',
#  'essay194.txt',
#  'essay195.ann',
#  'essay195.txt',
#  'essay196.ann',
#  'essay196.txt',
#  'essay197.ann',
#  'essay197.txt',
#  'essay198.ann',
#  'essay198.txt',
#  'essay199.ann',
#  'essay199.txt',
#  'essay200.ann',
#  'essay200.txt',
#  'essay201.ann',
#  'essay201.txt',
#  'essay202.ann',
#  'essay202.txt',
#  'essay203.ann',
#  'essay203.txt',
#  'essay204.ann',
#  'essay204.txt',
#  'essay205.ann',
#  'essay205.txt',
#  'essay206.ann',
#  'essay206.txt',
#  'essay207.ann',
#  'essay207.txt',
#  'essay208.ann',
#  'essay208.txt',
#  'essay209.ann',
#  'essay209.txt',
#  'essay210.ann',
#  'essay210.txt',
#  'essay211.ann',
#  'essay211.txt',
#  'essay212.ann',
#  'essay212.txt',
#  'essay213.ann',
#  'essay213.txt',
#  'essay214.ann',
#  'essay214.txt',
#  'essay215.ann',
#  'essay215.txt',
#  'essay216.ann',
#  'essay216.txt',
#  'essay217.ann',
#  'essay217.txt',
#  'essay218.ann',
#  'essay218.txt',
#  'essay219.ann',
#  'essay219.txt',
#  'essay220.ann',
#  'essay220.txt',
#  'essay221.ann',
#  'essay221.txt',
#  'essay222.ann',
#  'essay222.txt',
#  'essay223.ann',
#  'essay223.txt',
#  'essay224.ann',
#  'essay224.txt',
#  'essay225.ann',
#  'essay225.txt',
#  'essay226.ann',
#  'essay226.txt',
#  'essay227.ann',
#  'essay227.txt',
#  'essay228.ann',
#  'essay228.txt',
#  'essay229.ann',
#  'essay229.txt',
#  'essay230.ann',
#  'essay230.txt',
#  'essay231.ann',
#  'essay231.txt',
#  'essay232.ann',
#  'essay232.txt',
#  'essay233.ann',
#  'essay233.txt',
#  'essay234.ann',
#  'essay234.txt',
#  'essay235.ann',
#  'essay235.txt',
#  'essay236.ann',
#  'essay236.txt',
#  'essay237.ann',
#  'essay237.txt',
#  'essay238.ann',
#  'essay238.txt',
#  'essay239.ann',
#  'essay239.txt',
#  'essay240.ann',
#  'essay240.txt',
#  'essay241.ann',
#  'essay241.txt',
#  'essay242.ann',
#  'essay242.txt',
#  'essay243.ann',
#  'essay243.txt',
#  'essay244.ann',
#  'essay244.txt',
#  'essay245.ann',
#  'essay245.txt',
#  'essay246.ann',
#  'essay246.txt',
#  'essay247.ann',
#  'essay247.txt',
#  'essay248.ann',
#  'essay248.txt',
#  'essay249.ann',
#  'essay249.txt',
#  'essay250.ann',
#  'essay250.txt',
#  'essay251.ann',
#  'essay251.txt',
#  'essay252.ann',
#  'essay252.txt',
#  'essay253.ann',
#  'essay253.txt',
#  'essay254.ann',
#  'essay254.txt',
#  'essay255.ann',
#  'essay255.txt',
#  'essay256.ann',
#  'essay256.txt',
#  'essay257.ann',
#  'essay257.txt',
#  'essay258.ann',
#  'essay258.txt',
#  'essay259.ann',
#  'essay259.txt',
#  'essay260.ann',
#  'essay260.txt',
#  'essay261.ann',
#  'essay261.txt',
#  'essay262.ann',
#  'essay262.txt',
#  'essay263.ann',
#  'essay263.txt',
#  'essay264.ann',
#  'essay264.txt',
#  'essay265.ann',
#  'essay265.txt',
#  'essay266.ann',
#  'essay266.txt',
#  'essay267.ann',
#  'essay267.txt',
#  'essay268.ann',
#  'essay268.txt',
#  'essay269.ann',
#  'essay269.txt',
#  'essay270.ann',
#  'essay270.txt',
#  'essay271.ann',
#  'essay271.txt',
#  'essay272.ann',
#  'essay272.txt',
#  'essay273.ann',
#  'essay273.txt',
#  'essay274.ann',
#  'essay274.txt',
#  'essay275.ann',
#  'essay275.txt',
#  'essay276.ann',
#  'essay276.txt',
#  'essay277.ann',
#  'essay277.txt',
#  'essay278.ann',
#  'essay278.txt',
#  'essay279.ann',
#  'essay279.txt',
#  'essay280.ann',
#  'essay280.txt',
#  'essay281.ann',
#  'essay281.txt',
#  'essay282.ann',
#  'essay282.txt',
#  'essay283.ann',
#  'essay283.txt',
#  'essay284.ann',
#  'essay284.txt',
#  'essay285.ann',
#  'essay285.txt',
#  'essay286.ann',
#  'essay286.txt',
#  'essay287.ann',
#  'essay287.txt',
#  'essay288.ann',
#  'essay288.txt',
#  'essay289.ann',
#  'essay289.txt',
#  'essay290.ann',
#  'essay290.txt',
#  'essay291.ann',
#  'essay291.txt',
#  'essay292.ann',
#  'essay292.txt',
#  'essay293.ann',
#  'essay293.txt',
#  'essay294.ann',
#  'essay294.txt',
#  'essay295.ann',
#  'essay295.txt',
#  'essay296.ann',
#  'essay296.txt',
#  'essay297.ann',
#  'essay297.txt',
#  'essay298.ann',
#  'essay298.txt',
#  'essay299.ann',
#  'essay299.txt',
#  'essay300.ann',
#  'essay300.txt',
#  'essay301.ann',
#  'essay301.txt',
#  'essay302.ann',
#  'essay302.txt',
#  'essay303.ann',
#  'essay303.txt',
#  'essay304.ann',
#  'essay304.txt',
#  'essay305.ann',
#  'essay305.txt',
#  'essay306.ann',
#  'essay306.txt',
#  'essay307.ann',
#  'essay307.txt',
#  'essay308.ann',
#  'essay308.txt',
#  'essay309.ann',
#  'essay309.txt',
#  'essay310.ann',
#  'essay310.txt',
#  'essay311.ann',
#  'essay311.txt',
#  'essay312.ann',
#  'essay312.txt',
#  'essay313.ann',
#  'essay313.txt',
#  'essay314.ann',
#  'essay314.txt',
#  'essay315.ann',
#  'essay315.txt',
#  'essay316.ann',
#  'essay316.txt',
#  'essay317.ann',
#  'essay317.txt',
#  'essay318.ann',
#  'essay318.txt',
#  'essay319.ann',
#  'essay319.txt',
#  'essay320.ann',
#  'essay320.txt',
#  'essay321.ann',
#  'essay321.txt',
#  'essay322.ann',
#  'essay322.txt',
#  'essay323.ann',
#  'essay323.txt',
#  'essay324.ann',
#  'essay324.txt',
#  'essay325.ann',
#  'essay325.txt',
#  'essay326.ann',
#  'essay326.txt',
#  'essay327.ann',
#  'essay327.txt',
#  'essay328.ann',
#  'essay328.txt',
#  'essay329.ann',
txt', 'essay179.txt', 'essay180.txt', 'essay181.txt', 'essay182.txt', 'essay183.txt', 'essay184.txt', 'essay185.txt', 'essay186.txt', 'essay187.txt', 'essay188.txt', 'essay189.txt', 'essay190.txt', 'essay191.txt', 'essay192.txt', 'essay193.txt', 'essay194.txt', 'essay195.txt', 'essay196.txt', 'essay197.txt', 'essay198.txt', 'essay199.txt', 'essay200.txt', 'essay201.txt', 'essay202.txt', 'essay203.txt', 'essay204.txt', 'essay205.txt', 'essay206.txt', 'essay207.txt', 'essay208.txt', 'essay209.txt', 'essay210.txt', 'essay211.txt', 'essay212.txt', 'essay213.txt', 'essay214.txt', 'essay215.txt', 'essay216.txt', 'essay217.txt', 'essay218.txt', 'essay219.txt', 'essay220.txt', 'essay221.txt', 'essay222.txt', 'essay223.txt', 'essay224.txt', 'essay225.txt', 'essay226.txt', 'essay227.txt', 'essay228.txt', 'essay229.txt', 'essay230.txt', 'essay231.txt', 'essay232.txt', 'essay233.txt', 'essay234.txt', 'essay235.txt', 'essay236.txt', 'essay237.txt', 'essay238.txt', 'essay239.txt', 'essay240.txt', 'essay241.txt', 'essay242.txt', 'essay243.txt', 'essay244.txt', 'essay245.txt', 'essay246.txt', 'essay247.txt', 'essay248.txt', 'essay249.txt', 'essay250.txt', ...

# %% [markdown]
# # Anzahl MajorClaims, Claims, Premissen und Beziehungen zählen

# %%
def count_entities(files_list):
    data = []
    for file_path in files_list:
        file_name = os.path.basename(file_path)
        majorclaims = 0
        claims = 0
        premises = 0
        stances = 0
        relation = 0
        with open(file_path, 'r') as file:
            lines = file.readlines()
            for line in lines:
                if line.startswith('T'):
                    entity = line.split('\t')[1].split(' ')[0]
                    if entity == 'MajorClaim':
                        majorclaims += 1
                    elif entity == 'Claim':
                        claims += 1
                    elif entity == 'Premise':
                        premises += 1
                elif line.startswith('A'):
                    entity = line.split('\t')[1].split(' ')[0]
                    if entity == 'Stance':
                        stances += 1
                elif line.startswith('R'):
                    relation += 1

        data.append({'FileName': file_name,
                     'MajorClaims': majorclaims,
                     'Claims': claims,
                     'Premises': premises,
                     'Stances': stances,
                     'Relations': relation,
                     'Total': majorclaims + claims + premises + stances + relation})
    
    df = pd.DataFrame(data)
    
    return df

# %%
# example
count_df = count_entities(files_directory)

# sort the files by the number of entities
count_df = count_df.sort_values(by=['MajorClaims', 'Claims', 'Premises', 'Stances', 'Relations'], ascending=False)
count_df
# Out:
#          FileName  MajorClaims  Claims  Premises  Stances  Relations  Total
# 188  essay189.ann            3       8        12        8         12     43
# 288  essay289.ann            3       5        16        5         16     45
# 58   essay059.ann            3       5        11        5         11     35
# 121  essay122.ann            3       5        11        5         11     35
# 80   essay081.ann            3       4        13        4         13     37
# ..            ...          ...     ...       ...      ...        ...    ...
# 40   essay041.ann            1       2         6        2          6     17
# 319  essay320.ann            1       2         6        2          6     17
# 335  essay336.ann            1       2         6        2          6     17
# 364  essay365.ann            1       2         6        2          6     17
# 45   essay046.ann            1       2         5        2          5     15
#
# [402 rows x 7 columns]

# %%
count_df_sorted = count_df.sort_values(by=['Total'], ascending=False)
count_df_sorted
# Out:
#          FileName  MajorClaims  Claims  Premises  Stances  Relations  Total
# 168  essay169.ann            2       6        20        6         20     54
# 160  essay161.ann            2       8        16        8         16     50
# 153  essay154.ann            2       6        18        6         18     50
# 311  essay312.ann            2       4        19        4         19     48
# 285  essay286.ann            2       5        18        5         18     48
# ..            ...          ...     ...       ...      ...        ...    ...
# 382  essay383.ann            1       4         3        4          3     15
# 334  essay335.ann            1       4         3        4          3     15
# 170  essay171.ann            2       2         4        2          4     14
# 139  essay140.ann            2       2         4        2          4     14
# 87   essay088.ann            2       3         2        3          2     12
#
# [402 rows x 7 columns]

# %%
# plot count of entities
import matplotlib.pyplot as plt

def plot_entities_count(df):
    df.plot(x='FileName', y=['Total', 'MajorClaims', 'Claims', 'Premises', 'Stances', 'Relations'], kind='bar', figsize=(20,10))
    plt.show()

plot_entities_count(count_df_sorted)

# %% [markdown]
# # ANN-File annotieren

# %% [markdown]
# ## Var1

# %%
def parse_brat_annotation(files_path, files_name):
    """
    Formatiert die Annotationen in einer .ann-Datei in ein Pandas DataFrame. Dazu gehören die Entitäten, Attribute und Beziehungen
    Args:
        file_path (str): Pfad zur .ann-Datei
    Returns:
        pandas.DataFrame: Ein DataFrame mit den Annotationen
    """
    entities = []
    attributes = []
    relations = []

    path = files_path + files_name

    with open(path, 'r') as file:
        lines = file.readlines()

    for line in lines: # Iteriert über alle Zeilen in der Datei
        parts = line.strip().split('\t') # Teilt eine Zeile in durch Tabulatoren getrennte Teile 
        if parts[0].startswith('T'): # Wenn Zeile mit 'T' beginnt // Claims, MajorClaims, Premises
            entity_id = parts[0]
            entity_info = parts[1].split(' ')
            entity_type = entity_info[0]
            entity_start = int(entity_info[1])
            entity_end = int(entity_info[2])
            entity_text = parts[2]
            entities.append({

                'id': entity_id,
                'type': entity_type,
                'start': entity_start,
                'end': entity_end,
                'text': entity_text
            })
        elif parts[0].startswith('A'): # Wenn Zeile mit 'A' beginnt // Attribute
            attribute_id = parts[0]
            attribute_info = parts[1].split(' ')
            attribute_type = attribute_info[0]
            target_id = attribute_info[1]
            #attribute_value = parts[2] if len(parts) > 2 else None
            attribute_value = attribute_info[2]
            attributes.append({
                'id': attribute_id,
                'type': attribute_type,
                'target': target_id,
                'value': attribute_value
            })
        elif parts[0].startswith('R'): # Wenn Zeile mit 'R' beginnt
            relation_id = parts[0]
            relation_info = parts[1].split(' ') 
            relation_type = relation_info[0]
            arg1 = relation_info[1].split(':')[1]
            arg2 = relation_info[2].split(':')[1]
            relations.append({
                'id': relation_id,
                'arg1_from': arg1,
                'type': relation_type,
                'arg2_to': arg2
            })

    for entity in entities:
        # Mit nachfolgendem Code ist kein merge notwendig
        # Add stance to entities
        # Wenn 'target' der Attribute und 'ID' der Entities übereinstimmen, dann wird 'value' aus den Attributen zu Entities als Stance hinzugefügt
        # Mit next() wird das erste Element zurückgegeben, das den Bedingungen entspricht und None, wenn kein Element gefunden wird
        entity['stance'] = next((attr['value'] for attr in attributes if attr['target'] == entity['id']), None)
        #entity['stance'] = next((attr['value'] for attr in attributes if attr['target'] == entity['id'] and attr['type'] == 'Stance'), None)

        # Add relation to claims
        # Wenn 'arg1_from' der Relations und 'ID' der Entities übereinstimmen, dann wird:
        # 1: 'type' aus den Relations zu Entities als Relation hinzugefügt
        # 2: 'arg2_to' aus den Relations zu Entities als Relation_target hinzugefügt. Das ist der claim auf der sich die Relation bezieht
        # Mit next() wird das erste Element zurückgegeben, das den Bedingungen entspricht und None, wenn kein Element gefunden wird
        entity['relation'] = next((rel['type'] for rel in relations if rel['arg1_from'] == entity['id']), None)
        entity['relation_target'] = next((rel['arg2_to'] for rel in relations if rel['arg1_from'] == entity['id']), None)
           

    # turn data into a dataframe
    entities_df = pd.DataFrame(entities)
    attributes_df = pd.DataFrame(attributes)
    relations_df = pd.DataFrame(relations)

    return entities_df, attributes_df, relations_df

# %%
# Example usage
entities, attributes, relations = parse_brat_annotation(FILES_PATH, example_file)
entities
# Out:
#      id        type  start   end  \
# 0    T1  MajorClaim    503   575
# 1    T2  MajorClaim   2154  2231
# 2    T3       Claim    591   714
# 3    T4     Premise    716   851
# 4    T5     Premise    853  1086
# 5    T6     Premise   1088  1191
# 6    T7       Claim   1332  1376
# 7    T8     Premise   1212  1301
# 8    T9     Premise   1387  1492
# 9   T10     Premise   1549  1846
# 10  T11       Claim   1927  1992
#
#                                                  text   stance  relation  \
# 0   we should attach more importance to cooperatio...     None      None
# 1   a more cooperative attitudes towards life is m...     None      None
# 2   through cooperation, children can learn about ...      For      None
# 3   What we acquired from team work is not only ho...     None  supports
# 4   During the process of cooperation, children ca...     None  supports
# 5   All of these skills help them to get on well w...     None  supports
# 6        competition makes the society more effective  Against      None
# 7   the significance of competition is that how to...     None  supports
# 8   when we consider about the question that how t...     None  supports
# 9   Take Olympic games which is a form of competit...     None  supports
# 10  without the cooperation, there would be no vic...      For      None
#
#    relation_target
# 0             None
# 1             None
# 2             None
# 3               T3
# 4               T3
# 5               T3
# 6             None
# 7               T7
# 8              T11
# 9              T11
# 10            None

# %%
entities.sort_values('type')
entities.drop(columns=['start', 'end'], inplace=True)
entities
# Out:
#      id        type                                               text  \
# 0    T1  MajorClaim  we should attach more importance to cooperatio...
# 1    T2  MajorClaim  a more cooperative attitudes towards life is m...
# 2    T3       Claim  through cooperation, children can learn about ...
# 3    T4     Premise  What we acquired from team work is not only ho...
# 4    T5     Premise  During the process of cooperation, children ca...
# 5    T6     Premise  All of these skills help them to get on well w...
# 6    T7       Claim       competition makes the society more effective
# 7    T8     Premise  the significance of competition is that how to...
# 8    T9     Premise  when we consider about the question that how t...
# 9   T10     Premise  Take Olympic games which is a form of competit...
# 10  T11       Claim  without the cooperation, there would be no vic...
#
#      stance  relation relation_target
# 0      None      None            None
# 1      None      None            None
# 2       For      None            None
# 3      None  supports              T3
# 4      None  supports              T3
# 5      None  supports              T3
# 6   Against      None            None
# 7      None  supports              T7
# 8      None  supports             T11
# 9      None  supports             T11
# 10      For      None            None

# %%
def count_entity_types_per_file(files_path, files_list):
    entity_counts = {}

    for file in files_list:
        entities_df, _, _ = parse_brat_annotation(files_path, file)
        entity_type_counts = entities_df['type'].value_counts().to_dict()
        entity_counts[file] = entity_type_counts

    entity_counts_df = pd.DataFrame(entity_counts).T#.fillna(0)

    return entity_counts_df

# Example usage
entity_counts_df = count_entity_types_per_file(FILES_PATH, ann_files_list)
entity_counts_df

# %%
entity_counts_df.describe().round(1)

# %%
entity_counts_df.sort_values('MajorClaim', ascending=False)

# %%
entity_counts_df.sort_values('Claim', ascending=False)

# %%
entity_counts_df.sort_values('Premise', ascending=False)

# %%
# plot entity counts
import matplotlib.pyplot as plt

entity_counts_df.plot(kind='bar', stacked=True, figsize=(15, 5))
plt.title('Entity counts per file')
plt.show()

# %%
# entities_df für di ersten 10 Dateien
 
for file in ann_files_list[:10]:
    entities, _, _ = parse_brat_annotation(FILES_PATH, file)
    print(file)
    
    print(entities.sort_values('type'))
    print('-------------------')

# %% [markdown]
# ## Var 2

# %%
def parse_brat_annotation2(files_path, files_name):
    """
    Formatiert die Annotationen in einer .ann-Datei in ein Pandas DataFrame. Dazu gehören die Entitäten, Attribute und Beziehungen
    Args:
        file_path (str): Pfad zur .ann-Datei
    Returns:
        pandas.DataFrame: Ein DataFrame mit den Annotationen
    """
    entities = []
    attributes = []
    relations = []

    path = files_path + files_name

    with open(path, 'r') as file:
        lines = file.readlines()

    for line in lines: # Iteriert über alle Zeilen in der Datei
        parts = line.strip().split('\t') # Teilt eine Zeile in durch Tabulatoren getrennte Teile 
        if parts[0].startswith('T'): # Wenn Zeile mit 'T' beginnt // Claims, MajorClaims, Premises
            entity_id = parts[0]
            entity_info = parts[1].split(' ')
            entity_type = entity_info[0]
            entity_start = int(entity_info[1])
            entity_end = int(entity_info[2])
            entity_text = parts[2]
            entities.append({

                'id': entity_id,
                'type': entity_type,
                #'start': entity_start,
                #'end': entity_end,
                'text': entity_text
            })
        elif parts[0].startswith('A'): # Wenn Zeile mit 'A' beginnt // Attribute
            attribute_id = parts[0]
            attribute_info = parts[1].split(' ')
            attribute_type = attribute_info[0]
            target_id = attribute_info[1]
            #attribute_value = parts[2] if len(parts) > 2 else None
            attribute_value = attribute_info[2]
            attributes.append({
                'id': attribute_id,
                'type': attribute_type,
                'target': target_id,
                'value': attribute_value
            })
        elif parts[0].startswith('R'): # Wenn Zeile mit 'R' beginnt
            relation_id = parts[0]
            relation_info = parts[1].split(' ') 
            relation_type = relation_info[0]
            arg1 = relation_info[1].split(':')[1]
            arg2 = relation_info[2].split(':')[1]
            relations.append({
                'id': relation_id,
                'arg1_from': arg1,
                'type': relation_type,
                'arg2_to': arg2
            })

    # turn data into a dataframe
    #entities_df = pd.DataFrame(entities)
    #attributes_df = pd.DataFrame(attributes)
    #relations_df = pd.DataFrame(relations)

    #return entities_df, attributes_df, relations_df
    return entities, attributes, relations

# %%
# Example usage
entities, attributes, relations = parse_brat_annotation2(FILES_PATH, example_file)
entities

# %%
attributes

# %%
relations

# %%
df = pd.DataFrame(entities)
df

# %% [markdown]
# ## Var3

# %%
import os
import re
import pandas as pd

def parse_ann_file(filepath):
    # Initialize dictionaries to hold the different argument units and their stances
    major_claims = []
    claims = []
    premises = []

    # Dictionary to map argument unit IDs to their stance if available
    stances = {}

    with open(filepath, 'r') as file:
        for line in file:
            # Match argument units (MajorClaim, Claim, Premise)
            if line.startswith("T"):
                parts = line.strip().split("\t")
                unit_id, unit_type, text = parts[0], parts[1].split()[0], parts[2]

                # Parse each argument unit by type
                if unit_type == "MajorClaim":
                    major_claims.append({"text": text, "stance": stances.get(unit_id, None)})
                elif unit_type == "Claim":
                    claims.append({"text": text, "stance": stances.get(unit_id, None)})
                elif unit_type == "Premise":
                    premises.append({"text": text, "stance": stances.get(unit_id, None)})

            # Match stance annotations
            elif line.startswith("A"):
                stance_parts = line.strip().split("\t")
                if len(stance_parts) >= 3:
                    _, stance_type, target_id = stance_parts[0], stance_parts[1].split()[0], stance_parts[1].split()[1]
                    stance_value = stance_parts[2]

                    # Only consider stance type if it is 'Stance'
                    if stance_type == "Stance":
                        stances[target_id] = stance_value

    # Return the extracted data as dictionaries
    return {"MajorClaims": major_claims, "Claims": claims, "Premises": premises}

def process_files_in_directory(directory):
    # Initialize a list to collect data for each file
    data = []

    # Process each .ann file in the specified directory
    for filename in os.listdir(directory):
        if filename.endswith(".ann"):
            filepath = os.path.join(directory, filename)
            file_data = parse_ann_file(filepath)
            file_data["Filename"] = filename  # Include the filename for reference
            data.append(file_data)

    # Convert the list of dictionaries into a pandas DataFrame
    df = pd.DataFrame(data)

    # Convert columns with argument lists into lists of texts and stances for easier reading
    df["MajorClaims"] = df["MajorClaims"].apply(lambda lst: [(item["text"], item["stance"]) for item in lst])
    df["Claims"] = df["Claims"].apply(lambda lst: [(item["text"], item["stance"]) for item in lst])
    df["Premises"] = df["Premises"].apply(lambda lst: [(item["text"], item["stance"]) for item in lst])

    return df

# Usage
df = process_files_in_directory(FILES_PATH)

# Print or save the DataFrame as needed
df
# Out:
#                                            MajorClaims  \
# 0    [(we should attach more importance to cooperat...
# 1    [(they are able to sustain their cultural iden...
# 2    [(it has contributed to the economic developme...
# 3    [(this industry has affected the cultural attr...
# 4    [(one who studies overseas will gain many skil...
# ..                                                 ...
# 397  [(it is necessary for universities to respect ...
# 398  [(this is a worrying tread which has negative ...
# 399  [(governments should devote a greater portion ...
# 400  [(fatherhood is a as vital part of a healty pa...
# 401  [(both of studying hard and playing sports are...
#
#                                                 Claims  \
# 0    [(through cooperation, children can learn abou...
# 1    [(sustaining the cultural values of immigrants...
# 2    [(tourism has clearly improved lives in the to...
# 3    [(the tourism bring large profit for the desti...
# 4    [(studying at an overseas university gives ind...
# ..                                                 ...
# 397  [(many different characters exist between male...
# 398  [(This gives children the idea that it is not ...
# 399  [(society should be educated and became aware ...
# 400  [(The first reason why the father's role shoul...
# 401  [(studying hard will give children a better fu...
#
#                                               Premises      Filename
# 0    [(What we acquired from team work is not only ...  essay001.ann
# 1    [(maintaining one’s cultural identity is a key...  essay002.ann
# 2    [(international tourism promotes many aspects ...  essay003.ann
# 3    [(tourists from different cultures will probab...  essay004.ann
# 4    [(Compared to the peers studying in the home c...  essay005.ann
# ..                                                 ...           ...
# 397  [(Most of male students tend to use their left...  essay398.ann
# 398  [(The first impression of the celebrities seem...  essay399.ann
# 399  [(decreasing the number of patients in the hea...  essay400.ann
# 400  [(the role models within a family play a signi...  essay401.ann
# 401  [(Studying hard gives children with a plenty o...  essay402.ann
#
# [402 rows x 4 columns]

# %%
df['MajorClaims'][0]
# Out:
# [('we should attach more importance to cooperation during primary education',
#   None),
#  ("a more cooperative attitudes towards life is more profitable in one's success",
#   None)]

# %%
df['Claims'][0]
# Out:
# [('through cooperation, children can learn about interpersonal skills which are significant in the future life of all students',
#   None),
#  ('competition makes the society more effective', None),
#  ('without the cooperation, there would be no victory of competition', None)]

# %%
df['Claims'][0]
# Out:
# [('through cooperation, children can learn about interpersonal skills which are significant in the future life of all students',
#   None),
#  ('competition makes the society more effective', None),
#  ('without the cooperation, there would be no victory of competition', None)]

# %% [markdown]
# ## Var4

# %%
import pandas as pd
import re
import os

def parse_ann_file(file_path):
    with open(file_path, 'r') as file:
        content = file.readlines()
    
    major_claims = []
    claims = []
    premises = []
    stances = {}
    relations = []

    for line in content:
        if line.startswith('T'):
            parts = line.strip().split('\t')
            t_number = parts[0]
            annotation = parts[1].split()
            annotation_type = annotation[0]
            sentence = parts[2]

            if annotation_type == 'MajorClaim':
                major_claims.append({'id': t_number, 'Sentence': sentence})
            elif annotation_type == 'Claim':
                claims.append({'id': t_number, 'Sentence': sentence})
            elif annotation_type == 'Premise':
                premises.append({'id': t_number, 'Sentence': sentence})
        
        elif line.startswith('A'):
            parts = line.strip().split('\t')
            annotation = parts[1].split()
            t_number = annotation[1]
            stance = annotation[2]
            stances[t_number] = stance
        
        elif line.startswith('R'):
            parts = line.strip().split('\t')
            annotation = parts[1].split()
            relation_type = annotation[0]
            arg1 = annotation[1].split(':')[1]
            arg2 = annotation[2].split(':')[1]
            relations.append({'Relation': relation_type, 'Arg1': arg1, 'Arg2': arg2})

    # Add stances to claims
    for claim in claims:
        t_number = claim['id']
        claim['Stance'] = stances.get(t_number, '')

    # Add relations to premises
    for premise in premises:
        t_number = premise['id']
        related_relations = [rel for rel in relations if rel['Arg1'] == t_number]
        premise['Relations'] = [{'Relation': rel['Relation'], 'Target': rel['Arg2']} for rel in related_relations]

    return {
        'MajorClaims': major_claims,
        'Claims': claims,
        'Premises': premises,
        'Stances': stances,
        'Relations': relations
    }

def create_dataframe_from_ann_files(directory):
    data = []
    for filename in os.listdir(directory):
        if filename.endswith('.ann'):
            file_path = os.path.join(directory, filename)
            parsed_data = parse_ann_file(file_path)
            data.append({
                'file-name': filename,
                'MajorClaims': parsed_data['MajorClaims'],
                'Claims': parsed_data['Claims'],
                'Premises': parsed_data['Premises'],
                'Stances': parsed_data['Stances'],
                'Relations': parsed_data['Relations']
            })
    
    df = pd.DataFrame(data, columns=['file-name', 'MajorClaims', 'Claims', 'Premises', 'Stances', 'Relations'])
    return df

# Example usage
print(FILES_PATH)
df = create_dataframe_from_ann_files(FILES_PATH)
df
# Out:
# Essays/ArgumentAnnotatedEssays-2.0/brat-project-final/
#         file-name                                        MajorClaims  \
# 0    essay001.ann  [{'T-Number': 'T1', 'Sentence': 'we should att...
# 1    essay002.ann  [{'T-Number': 'T1', 'Sentence': 'they are able...
# 2    essay003.ann  [{'T-Number': 'T1', 'Sentence': 'it has contri...
# 3    essay004.ann  [{'T-Number': 'T1', 'Sentence': 'this industry...
# 4    essay005.ann  [{'T-Number': 'T1', 'Sentence': 'one who studi...
# ..            ...                                                ...
# 397  essay398.ann  [{'T-Number': 'T2', 'Sentence': 'it is necessa...
# 398  essay399.ann  [{'T-Number': 'T1', 'Sentence': 'this is a wor...
# 399  essay400.ann  [{'T-Number': 'T1', 'Sentence': 'governments s...
# 400  essay401.ann  [{'T-Number': 'T1', 'Sentence': 'fatherhood is...
# 401  essay402.ann  [{'T-Number': 'T1', 'Sentence': 'both of study...
#
#                                                 Claims  \
# 0    [{'T-Number': 'T3', 'Sentence': 'through coope...
# 1    [{'T-Number': 'T4', 'Sentence': 'sustaining th...
# 2    [{'T-Number': 'T3', 'Sentence': 'tourism has c...
# 3    [{'T-Number': 'T3', 'Sentence': 'the tourism b...
# 4    [{'T-Number': 'T3', 'Sentence': 'studying at a...
# ..                                                 ...
# 397  [{'T-Number': 'T1', 'Sentence': 'many differen...
# 398  [{'T-Number': 'T3', 'Sentence': 'This gives ch...
# 399  [{'T-Number': 'T3', 'Sentence': 'society shoul...
# 400  [{'T-Number': 'T5', 'Sentence': 'The first rea...
# 401  [{'T-Number': 'T8', 'Sentence': 'studying hard...
#
#                                               Premises  \
# 0    [{'T-Number': 'T4', 'Sentence': 'What we acqui...
# 1    [{'T-Number': 'T3', 'Sentence': 'maintaining o...
# 2    [{'T-Number': 'T4', 'Sentence': 'international...
# 3    [{'T-Number': 'T6', 'Sentence': 'tourists from...
# 4    [{'T-Number': 'T6', 'Sentence': 'Compared to t...
# ..                                                 ...
# 397  [{'T-Number': 'T3', 'Sentence': 'Most of male ...
# 398  [{'T-Number': 'T4', 'Sentence': 'The first imp...
# 399  [{'T-Number': 'T4', 'Sentence': 'decreasing th...
# 400  [{'T-Number': 'T3', 'Sentence': 'the role mode...
# 401  [{'T-Number': 'T3', 'Sentence': 'Studying hard...
#
#                                                Stances  \
# 0         {'T3': 'For', 'T7': 'Against', 'T11': 'For'}
# 1        {'T4': 'For', 'T10': 'For', 'T14': 'Against'}
# 2                           {'T3': 'For', 'T8': 'For'}
# 3          {'T3': 'Against', 'T4': 'For', 'T5': 'For'}
# 4    {'T3': 'For', 'T4': 'For', 'T5': 'For', 'T12':...
# ..                                                 ...
# 397  {'T1': 'For', 'T8': 'For', 'T10': 'For', 'T12'...
# 398            {'T3': 'For', 'T7': 'For', 'T9': 'For'}
# 399                        {'T3': 'For', 'T10': 'For'}
# 400                         {'T5': 'For', 'T8': 'For'}
# 401                        {'T8': 'For', 'T15': 'For'}
#
#                                              Relations
# 0    [{'Relation': 'supports', 'Arg1': 'T4', 'Arg2'...
# 1    [{'Relation': 'supports', 'Arg1': 'T9', 'Arg2'...
# 2    [{'Relation': 'supports', 'Arg1': 'T10', 'Arg2...
# 3    [{'Relation': 'supports', 'Arg1': 'T8', 'Arg2'...
# 4    [{'Relation': 'supports', 'Arg1': 'T6', 'Arg2'...
# ..                                                 ...
# 397  [{'Relation': 'supports', 'Arg1': 'T3', 'Arg2'...
# 398  [{'Relation': 'supports', 'Arg1': 'T4', 'Arg2'...
# 399  [{'Relation': 'supports', 'Arg1': 'T4', 'Arg2'...
# 400  [{'Relation': 'supports', 'Arg1': 'T3', 'Arg2'...
# 401  [{'Relation': 'supports', 'Arg1': 'T5', 'Arg2'...
#
# [402 rows x 6 columns]

# %%
df["MajorClaims"][0]
# Out:
# [{'T-Number': 'T1',
#   'Sentence': 'we should attach more importance to cooperation during primary education'},
#  {'T-Number': 'T2',
#   'Sentence': "a more cooperative attitudes towards life is more profitable in one's success"}]

# %%
df["Claims"][0]
# Out:
# [{'T-Number': 'T3',
#   'Sentence': 'through cooperation, children can learn about interpersonal skills which are significant in the future life of all students',
#   'Stance': 'For'},
#  {'T-Number': 'T7',
#   'Sentence': 'competition makes the society more effective',
#   'Stance': 'Against'},
#  {'T-Number': 'T11',
#   'Sentence': 'without the cooperation, there would be no victory of competition',
#   'Stance': 'For'}]

# %%
df["Premises"][0]
# Out:
# [{'T-Number': 'T4',
#   'Sentence': 'What we acquired from team work is not only how to achieve the same goal with others but more importantly, how to get along with others',
#   'Relations': [{'Relation': 'supports', 'Target': 'T3'}]},
#  {'T-Number': 'T5',
#   'Sentence': 'During the process of cooperation, children can learn about how to listen to opinions of others, how to communicate with others, how to think comprehensively, and even how to compromise with other team members when conflicts occurred',
#   'Relations': [{'Relation': 'supports', 'Target': 'T3'}]},
#  {'T-Number': 'T6',
#   'Sentence': 'All of these skills help them to get on well with other people and will benefit them for the whole life',
#   'Relations': [{'Relation': 'supports', 'Target': 'T3'}]},
#  {'T-Number': 'T8',
#   'Sentence': 'the significance of competition is that how to become more excellence to gain the victory',
#   'Relations': [{'Relation': 'supports', 'Target': 'T7'}]},
#  {'T-Number': 'T9',
#   'Sentence': 'when we consider about the question that how to win the game, we always find that we need the cooperation',
#   'Relations': [{'Relation': 'supports', 'Target': 'T11'}]},
#  {'T-Number': 'T10',
#   'Sentence': 'Take Olympic games which is a form of competition for instance, it is hard to imagine how an athlete could win the game without the training of his or her coach, and the help of other professional staffs such as the people who take care of his diet, and those who are in charge of the medical care',
#   'Relations': [{'Relation': 'supports', 'Target': 'T11'}]}]

# %% [markdown]
# # V2 - pybrat
# didnt work

# %% [markdown]
# # V3 brat-parser

# %%
#pip install mendelai-brat-parser
# Out:
# Collecting mendelai-brat-parser
#   Downloading mendelai_brat_parser-0.0.11.tar.gz (4.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: mendelai-brat-parser
#   Building wheel for mendelai-brat-parser (setup.py): started
#   Building wheel for mendelai-brat-parser (setup.py): finished with status 'done'
#   Created wheel for mendelai-brat-parser: filename=mendelai_brat_parser-0.0.11-py3-none-any.whl size=4933 sha256=a44686a70d0b711f754018b8211845bbba1d012ba752720cddea50268012216b
#   Stored in directory: c:\users\ben-s\appdata\local\pip\cache\wheels\74\3f\c2\069a65b2deaa01ccf6fc1b494d6e2900f235f67431245c2597
# Successfully built mendelai-brat-parser
# Installing collected packages: mendelai-brat-parser
# Successfully installed mendelai-brat-parser-0.0.11
# Note: you may need to restart the kernel to use updated packages.

# %%
from brat_parser import get_entities_relations_attributes_groups
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from brat_parser import get_entities_relations_attributes_groups
#
# File c:\Users\ben-s\anaconda3\envs\llm\Lib\site-packages\brat_parser.py:6
#       3 from dataclasses import dataclass
#       4 from typing import Dict, List, Sequence, Text, Tuple
# ----> 6 from smart_open import open
#       8 GROUPING_ENTITIES = frozenset(["And-Group", "Or-Group"])
#       9 GROUPING_RELATIONS = frozenset(["And", "Or"])
#
# ModuleNotFoundError: No module named 'smart_open'

# %%
entities, relations, attributes, groups = get_entities_relations_attributes_groups(example_file_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 entities, relations, attributes, groups = get_entities_relations_attributes_groups(file_path)
#
# NameError: name 'get_entities_relations_attributes_groups' is not defined

# %% [markdown]
# # V4 - stackoverflow

# %%
df = pd.read_csv(example_file_path, sep='^([^\s]*)\s', engine='python', header=None).drop(0, axis=1)
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\ben-s\AppData\Local\Temp\ipykernel_29444\1248168049.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(file_path, sep='^([^\s]*)\s', engine='python', header=None).drop(0, axis=1)
#       1                                                  2
# 0    T1  MajorClaim 503 575\twe should attach more impo...
# 1    T2  MajorClaim 2154 2231\ta more cooperative attit...
# 2    T3  Claim 591 714\tthrough cooperation, children c...
# 3    A1                                      Stance T3 For
# 4    T4  Premise 716 851\tWhat we acquired from team wo...
# 5    T5  Premise 853 1086\tDuring the process of cooper...
# 6    T6  Premise 1088 1191\tAll of these skills help th...
# 7    R1                           supports Arg1:T4 Arg2:T3
# 8    R2                           supports Arg1:T5 Arg2:T3
# 9    R3                           supports Arg1:T6 Arg2:T3
# 10   T7  Claim 1332 1376\tcompetition makes the society...
# 11   A2                                  Stance T7 Against
# 12   T8  Premise 1212 1301\tthe significance of competi...
# 13   T9  Premise 1387 1492\twhen we consider about the ...
# 14  T10  Premise 1549 1846\tTake Olympic games which is...
# 15  T11  Claim 1927 1992\twithout the cooperation, ther...
# 16   A3                                     Stance T11 For
# 17   R4                         supports Arg1:T10 Arg2:T11
# 18   R5                          supports Arg1:T9 Arg2:T11
# 19   R6                           supports Arg1:T8 Arg2:T7
